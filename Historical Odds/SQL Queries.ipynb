# %%
# #SQL Query to pivot odds to columns instead of rows
# CREATE VIEW refined_odds AS
# SELECT
#     event_id,
#     description,
#     market,
#     point,
#     snapshot_time,
#     MAX(CASE WHEN bookmaker = 'williamhill_us' THEN decimal_odds END) AS williamhill_us_odds,
#     MAX(CASE WHEN bookmaker = 'betonlineag' THEN decimal_odds END) AS betonlineag_odds,
#     MAX(CASE WHEN bookmaker = 'betmgm' THEN decimal_odds END) AS MGM_odds,
#     MAX(CASE WHEN bookmaker = 'draftkings' THEN decimal_odds END) AS DraftKings_odds,
#     MAX(CASE WHEN bookmaker = 'fanduel' THEN decimal_odds END) AS FanDuel_odds
# FROM
#     odds
# GROUP BY
#     event_id, description, market, point, snapshot_time;

# %%
#SQL Query to create a column for formatted times
# UPDATE refined_odds
# SET snapshot_time = strftime('%m-%d-%Y', substr(snapshot_time, 1, 10));

# %%
#SQL Query to create a table with only player points from fanduel

# CREATE TABLE fan_duel_player_points AS
# SELECT
#     *
# FROM
#     fanduel_Odds


# DELETE FROM fan_duel_player_points
# WHERE market != 'player_points';

# %%
#SQL Query to create a table with only player points from draftkings

# CREATE TABLE draftkings_player_points AS
# SELECT
#     *
# FROM
#     draftkings_Odds


# DELETE FROM draftkings_player_points
# WHERE market != 'player_points';
