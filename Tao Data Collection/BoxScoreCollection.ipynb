# %%
from nba_api.stats.endpoints import leaguegamefinder, boxscoretraditionalv2, boxscoresummaryv2, boxscoreadvancedv2
import requests
import pandas as pd
import sqlite3
import time

# %%
# Define the starting season and initialize a list for all box scores
batch_size = 20 # Number of games to process in each batch
delay_between_batches = 10 # Delay (in seconds) between batches
seasons = ['2019-20', '2020-21', '2021-22', '2022-23', '2023-24', '2024-25']  # Add seasons as needed

# Connect to SQLite database (creates the database if it doesn't exist)
conn = sqlite3.connect("1-10.db")
cursor = conn.cursor()

#Fetch all games for the specified seasons
all_games = []
for season in seasons:
    print(f"Fetching games for season {season}...")
    gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable=season, season_type_nullable='Regular Season')
    season_games_df = gamefinder.get_data_frames()[0]
    all_games.append(season_games_df)
    time.sleep(10)

# Combine games from all seasons
games_df = pd.concat(all_games, ignore_index=True)
games_df.to_csv('allgames.csv', index=False)  # Save to CSV for reference

# Get unique game IDs
game_ids = games_df['GAME_ID'].unique()
# Out:
# Fetching games for season 2019-20...
# Fetching games for season 2020-21...
# Fetching games for season 2021-22...
# Fetching games for season 2022-23...
# Fetching games for season 2023-24...
# Fetching games for season 2024-25...

# %%
# Step 2: Process games in batches
for i in range(0, len(game_ids), batch_size):
    batch = game_ids[i:i + batch_size]
    print(f"Processing batch {i // batch_size + 1} with {len(batch)} games...")

    for game_id in batch:
        try:
            # Fetch box score data for the game
            boxscoretrad = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id, timeout=60)

            # Extract PlayerStats
            player_basic_stats = boxscoretrad.player_stats.get_data_frame()
            player_basic_stats["GAME_ID"] = game_id
            
            # Extract TeamStats
            team_basic_stats = boxscoretrad.team_stats.get_data_frame()
            team_basic_stats["GAME_ID"] = game_id

            # Save data to SQLite database
            player_basic_stats.to_sql("player_basic_stats", conn, if_exists="append", index=False)
            team_basic_stats.to_sql("team_basic_stats", conn, if_exists="append", index=False)


        except Exception as e:
            print(f"Error processing game {game_id}: {e}")
            continue

    # Delay between batches
    print(f"Batch {i // batch_size + 1} completed. Waiting for {delay_between_batches} seconds...")
    time.sleep(delay_between_batches)

# Step 3: Verify Data Saved
print("All data successfully saved to SQLite database!")
# Out:
# Processing batch 1 with 20 games...
# Batch 1 completed. Waiting for 10 seconds...
# Processing batch 2 with 20 games...
# Batch 2 completed. Waiting for 10 seconds...
# Processing batch 3 with 20 games...
# Batch 3 completed. Waiting for 10 seconds...
# Processing batch 4 with 20 games...
# Batch 4 completed. Waiting for 10 seconds...
# Processing batch 5 with 20 games...
# Batch 5 completed. Waiting for 10 seconds...
# Processing batch 6 with 20 games...
# Batch 6 completed. Waiting for 10 seconds...
# Processing batch 7 with 20 games...
# Batch 7 completed. Waiting for 10 seconds...
# Processing batch 8 with 20 games...
# Batch 8 completed. Waiting for 10 seconds...
# Processing batch 9 with 20 games...
# Batch 9 completed. Waiting for 10 seconds...
# Processing batch 10 with 20 games...
# Batch 10 completed. Waiting for 10 seconds...
# Processing batch 11 with 20 games...
# Batch 11 completed. Waiting for 10 seconds...
# Processing batch 12 with 20 games...
# Batch 12 completed. Waiting for 10 seconds...
# Processing batch 13 with 20 games...
# Batch 13 completed. Waiting for 10 seconds...
# Processing batch 14 with 20 games...
# Batch 14 completed. Waiting for 10 seconds...
# Processing batch 15 with 20 games...
# Batch 15 completed. Waiting for 10 seconds...
# Processing batch 16 with 20 games...
# Batch 16 completed. Waiting for 10 seconds...
# Processing batch 17 with 20 games...
# Batch 17 completed. Waiting for 10 seconds...
# Processing batch 18 with 20 games...
# Batch 18 completed. Waiting for 10 seconds...
# Processing batch 19 with 20 games...
# Batch 19 completed. Waiting for 10 seconds...
# Processing batch 20 with 20 games...
# Batch 20 completed. Waiting for 10 seconds...
# Processing batch 21 with 20 games...
# Batch 21 completed. Waiting for 10 seconds...
# Processing batch 22 with 20 games...
# Batch 22 completed. Waiting for 10 seconds...
# Processing batch 23 with 20 games...
# Batch 23 completed. Waiting for 10 seconds...
# Processing batch 24 with 20 games...
# Batch 24 completed. Waiting for 10 seconds...
# Processing batch 25 with 20 games...
# Batch 25 completed. Waiting for 10 seconds...
# Processing batch 26 with 20 games...
# Batch 26 completed. Waiting for 10 seconds...
# Processing batch 27 with 20 games...
# Batch 27 completed. Waiting for 10 seconds...
# Processing batch 28 with 20 games...
# Batch 28 completed. Waiting for 10 seconds...
# Processing batch 29 with 20 games...
# Batch 29 completed. Waiting for 10 seconds...
# Processing batch 30 with 20 games...
# Batch 30 completed. Waiting for 10 seconds...
# Processing batch 31 with 20 games...
# Batch 31 completed. Waiting for 10 seconds...
# Processing batch 32 with 20 games...
# Batch 32 completed. Waiting for 10 seconds...
# Processing batch 33 with 20 games...
# Batch 33 completed. Waiting for 10 seconds...
# Processing batch 34 with 20 games...
# Batch 34 completed. Waiting for 10 seconds...
# Processing batch 35 with 20 games...
# Batch 35 completed. Waiting for 10 seconds...
# Processing batch 36 with 20 games...
# Batch 36 completed. Waiting for 10 seconds...
# Processing batch 37 with 20 games...
# Batch 37 completed. Waiting for 10 seconds...
# Processing batch 38 with 20 games...
# Batch 38 completed. Waiting for 10 seconds...
# Processing batch 39 with 20 games...
# Batch 39 completed. Waiting for 10 seconds...
# Processing batch 40 with 20 games...
# Batch 40 completed. Waiting for 10 seconds...
# Processing batch 41 with 20 games...
# Batch 41 completed. Waiting for 10 seconds...
# Processing batch 42 with 20 games...
# Batch 42 completed. Waiting for 10 seconds...
# Processing batch 43 with 20 games...
# Batch 43 completed. Waiting for 10 seconds...
# Processing batch 44 with 20 games...
# Batch 44 completed. Waiting for 10 seconds...
# Processing batch 45 with 20 games...
# Batch 45 completed. Waiting for 10 seconds...
# Processing batch 46 with 20 games...
# Batch 46 completed. Waiting for 10 seconds...
# Processing batch 47 with 20 games...
# Batch 47 completed. Waiting for 10 seconds...
# Processing batch 48 with 20 games...
# Batch 48 completed. Waiting for 10 seconds...
# Processing batch 49 with 20 games...
# Batch 49 completed. Waiting for 10 seconds...
# Processing batch 50 with 20 games...
# Batch 50 completed. Waiting for 10 seconds...
# Processing batch 51 with 20 games...
# Batch 51 completed. Waiting for 10 seconds...
# Processing batch 52 with 20 games...
# Batch 52 completed. Waiting for 10 seconds...
# Processing batch 53 with 20 games...
# Batch 53 completed. Waiting for 10 seconds...
# Processing batch 54 with 20 games...
# Batch 54 completed. Waiting for 10 seconds...
# Processing batch 55 with 20 games...
# Batch 55 completed. Waiting for 10 seconds...
# Processing batch 56 with 20 games...
# Batch 56 completed. Waiting for 10 seconds...
# Processing batch 57 with 20 games...
# Batch 57 completed. Waiting for 10 seconds...
# Processing batch 58 with 20 games...
# Batch 58 completed. Waiting for 10 seconds...
# Processing batch 59 with 20 games...
# Batch 59 completed. Waiting for 10 seconds...
# Processing batch 60 with 20 games...
# Batch 60 completed. Waiting for 10 seconds...
# Processing batch 61 with 20 games...
# Batch 61 completed. Waiting for 10 seconds...
# Processing batch 62 with 20 games...
# Batch 62 completed. Waiting for 10 seconds...
# Processing batch 63 with 20 games...
# Batch 63 completed. Waiting for 10 seconds...
# Processing batch 64 with 20 games...
# Batch 64 completed. Waiting for 10 seconds...
# Processing batch 65 with 20 games...
# Batch 65 completed. Waiting for 10 seconds...
# Processing batch 66 with 20 games...
# Batch 66 completed. Waiting for 10 seconds...
# Processing batch 67 with 20 games...
# Batch 67 completed. Waiting for 10 seconds...
# Processing batch 68 with 20 games...
# Batch 68 completed. Waiting for 10 seconds...
# Processing batch 69 with 20 games...
# Batch 69 completed. Waiting for 10 seconds...
# Processing batch 70 with 20 games...
# Batch 70 completed. Waiting for 10 seconds...
# Processing batch 71 with 20 games...
# Batch 71 completed. Waiting for 10 seconds...
# Processing batch 72 with 20 games...
# Batch 72 completed. Waiting for 10 seconds...
# Processing batch 73 with 20 games...
# Batch 73 completed. Waiting for 10 seconds...
# Processing batch 74 with 20 games...
# Batch 74 completed. Waiting for 10 seconds...
# Processing batch 75 with 20 games...
# Batch 75 completed. Waiting for 10 seconds...
# Processing batch 76 with 20 games...
# Batch 76 completed. Waiting for 10 seconds...
# Processing batch 77 with 20 games...
# Batch 77 completed. Waiting for 10 seconds...
# Processing batch 78 with 20 games...
# Batch 78 completed. Waiting for 10 seconds...
# Processing batch 79 with 20 games...
# Batch 79 completed. Waiting for 10 seconds...
# Processing batch 80 with 20 games...
# Batch 80 completed. Waiting for 10 seconds...
# Processing batch 81 with 20 games...
# Batch 81 completed. Waiting for 10 seconds...
# Processing batch 82 with 20 games...
# Batch 82 completed. Waiting for 10 seconds...
# Processing batch 83 with 20 games...
# Batch 83 completed. Waiting for 10 seconds...
# Processing batch 84 with 20 games...
# Batch 84 completed. Waiting for 10 seconds...
# Processing batch 85 with 20 games...
# Batch 85 completed. Waiting for 10 seconds...
# Processing batch 86 with 20 games...
# Batch 86 completed. Waiting for 10 seconds...
# Processing batch 87 with 20 games...
# Batch 87 completed. Waiting for 10 seconds...
# Processing batch 88 with 20 games...
# Batch 88 completed. Waiting for 10 seconds...
# Processing batch 89 with 20 games...
# Batch 89 completed. Waiting for 10 seconds...
# Processing batch 90 with 20 games...
# Batch 90 completed. Waiting for 10 seconds...
# Processing batch 91 with 20 games...
# Batch 91 completed. Waiting for 10 seconds...
# Processing batch 92 with 20 games...
# Batch 92 completed. Waiting for 10 seconds...
# Processing batch 93 with 20 games...
# Batch 93 completed. Waiting for 10 seconds...
# Processing batch 94 with 20 games...
# Batch 94 completed. Waiting for 10 seconds...
# Processing batch 95 with 20 games...
# Batch 95 completed. Waiting for 10 seconds...
# Processing batch 96 with 20 games...
# Batch 96 completed. Waiting for 10 seconds...
# Processing batch 97 with 20 games...
# Batch 97 completed. Waiting for 10 seconds...
# Processing batch 98 with 20 games...
# Batch 98 completed. Waiting for 10 seconds...
# Processing batch 99 with 20 games...
# Batch 99 completed. Waiting for 10 seconds...
# Processing batch 100 with 20 games...
# Batch 100 completed. Waiting for 10 seconds...
# Processing batch 101 with 20 games...
# Batch 101 completed. Waiting for 10 seconds...
# Processing batch 102 with 20 games...
# Batch 102 completed. Waiting for 10 seconds...
# Processing batch 103 with 20 games...
# Batch 103 completed. Waiting for 10 seconds...
# Processing batch 104 with 20 games...
# Batch 104 completed. Waiting for 10 seconds...
# Processing batch 105 with 20 games...
# Batch 105 completed. Waiting for 10 seconds...
# Processing batch 106 with 20 games...
# Batch 106 completed. Waiting for 10 seconds...
# Processing batch 107 with 20 games...
# Batch 107 completed. Waiting for 10 seconds...
# Processing batch 108 with 20 games...
# Batch 108 completed. Waiting for 10 seconds...
# Processing batch 109 with 20 games...
# Batch 109 completed. Waiting for 10 seconds...
# Processing batch 110 with 20 games...
# Batch 110 completed. Waiting for 10 seconds...
# Processing batch 111 with 20 games...
# Batch 111 completed. Waiting for 10 seconds...
# Processing batch 112 with 20 games...
# Batch 112 completed. Waiting for 10 seconds...
# Processing batch 113 with 20 games...
# Batch 113 completed. Waiting for 10 seconds...

# %%
# Step 2: Process games in batches
for i in range(0, len(game_ids), batch_size):
    batch = game_ids[i:i + batch_size]
    print(f"Processing batch {i // batch_size + 1} with {len(batch)} games...")

    for game_id in batch:
        try:
            # Fetch box score data for the game
            boxscore = boxscoresummaryv2.BoxScoreSummaryV2(game_id=game_id)
            boxscoreadv = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=game_id)
            boxscoretrad = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id)


            # Extract and add relevant data
            game_details = boxscore.game_summary.get_data_frame()
            inactive_players = boxscore.inactive_players.get_data_frame()
            team_stats = boxscoreadv.team_stats.get_data_frame()
            player_stats = boxscoreadv.player_stats.get_data_frame()

            # Tag data with the game ID for clarity
            game_details['GAME_ID'] = game_id
            inactive_players['GAME_ID'] = game_id
            team_stats['GAME_ID'] = game_id
            player_stats['GAME_ID'] = game_id

            # Save data to SQLite database
            game_details.to_sql('game_details', conn, if_exists='append', index=False)
            inactive_players.to_sql('inactive_players', conn, if_exists='append', index=False)
            player_stats.to_sql('player_stats', conn, if_exists='append', index=False)
            team_stats.to_sql('team_stats', conn, if_exists='append', index=False)
            
        except Exception as e:
            print(f"Failed to process game {game_id}: {e}")
            continue

    # Delay between batches to avoid rate limiting
    print(f"Batch {i // batch_size + 1} completed. Waiting for {delay_between_batches} seconds...")
    time.sleep(delay_between_batches)

# Step 3: Verify Data Saved
print("All data successfully saved to SQLite database!")

# Close the database connection
conn.close()
